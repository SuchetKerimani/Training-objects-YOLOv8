# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.3.1+cu121 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 33.6/107.7 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# %cd /content/drive/MyDrive/computervisiondetector/trainyolov8customdataset
# Out:
# /content/drive/MyDrive/computervisiondetector/trainyolov8customdataset

# %%
# !ls
# Out:
# data  data.yaml  runs  yolov8s.pt

# %%
# %cd /content/drive/MyDrive/computervisiondetector/trainyolov8customdataset

# !yolo task=detect mode=train model=yolov8s.pt data= data.yaml epochs=25 imgsz=224 plots=True
# Out:
# /content/drive/MyDrive/computervisiondetector/trainyolov8customdataset
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.3.1+cu121 CPU
# ...

# %%
# !ls /content/drive/MyDrive/computervisiondetector/trainyolov8customdataset/runs/detect/train3
# Out:
# args.yaml					    R_curve.png       train_batch30.jpg
# confusion_matrix.png				    results.csv       train_batch31.jpg
# events.out.tfevents.1723908308.41e604c3f86e.2422.0  results.png       train_batch32.jpg
# F1_curve.png					    train_batch0.jpg  val_batch0_labels.jpg
# P_curve.png					    train_batch1.jpg  val_batch0_pred.jpg
# PR_curve.png					    train_batch2.jpg  weights

# %%
Image(filename='/content/drive/MyDrive/computervisiondetector/trainyolov8customdataset/runs/detect/train3/confusion_matrix.png', width=600)

# %%
Image(filename='/content/drive/MyDrive/computervisiondetector/trainyolov8customdataset/runs/detect/train3/results.png', width=600)

# %%
Image(filename='/content/drive/MyDrive/computervisiondetector/trainyolov8customdataset/runs/detect/train3/val_batch0_pred.jpg', width=600)

# %%
# !yolo task=detect mode=val model= /content/drive/MyDrive/computervisiondetector/trainyolov8customdataset/runs/detect/train3/weights/best.pt   data=data.yaml
# Out:
# 2024-08-17 16:04:06.889902: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-17 16:04:07.026102: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-17 16:04:07.037614: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-17 16:04:07.069568: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/computervisiondetector/trainyolov8customdataset/runs/detect/train3/weights/best.pt conf=0.25 source=/content/drive/MyDrive/computervisiondetector/trainyolov8customdataset/data/test/images save=True
# Out:
# 2024-08-17 16:35:06.900123: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-17 16:35:06.923856: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-17 16:35:06.931089: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-17 16:35:06.950712: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
import glob
from IPython.display import Image, display

# Loop through the first 3 images in the directory
for image_path in glob.glob('/content/drive/MyDrive/computervisiondetector/trainyolov8customdataset/runs/detect/predict/*.jpg')[:3]:
    # Display the image
    display(Image(filename=image_path, width=600))
    print("\n")
